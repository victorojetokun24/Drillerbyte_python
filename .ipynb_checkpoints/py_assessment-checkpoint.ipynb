# %% [markdown]
# # ASSESSMENT

# %%
import numpy as np

# %%
class animal:
    def __init__(self, category,specie,number_of_legs):
        self.category = category
        self.specie = specie
        self.number_of_legs = number_of_legs
        #Adding functions
    def walking(self):
        print (f'The {self.specie} is walking.')

# %%
cat = animal('Cat family','Cat','4')

# %%
type(cat)
# Out:
# __main__.animal

# %%
cat.specie
# Out:
# 'Cat'

# %%
cat.walking()
# Out:
# The Cat is walking.

# %%
#Given the python list x = [[3,5,2],[6,0,1],[9,4,7]], what code snippet can be used to create a variable y with value of 7 from list x ?
x = [[3,5,2],[6,0,1],[9,4,7]]

# %%
type(x)
# Out:
# list

# %%
y = np.array(x)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y.ndim
# Out:
# 2

# %%
y[2][2]
# Out:
# 7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
af = pd.read_csv('dataset/movies_data.csv')

# %%
af.head(20)
# Out:
#     S/N                           Title  Year  Rating  Watched
# 0     1  The Nightmare Before Christmas  1993     3.9   4568.0
# 1     2                       The Mummy  1932     3.5   4388.0
# 2     3            Orphans of the Storm  1921     3.2   9062.0
# 3     4            The Object of Beauty  1991     2.8   6150.0
# 4     5                      Night Tide  1963     2.8   5126.0
# 5     6             One Magic Christmas  1985     3.8   5333.0
# 6     7                Muriel's Wedding  1994     3.5   6323.0
# 7     8                   Mother's Boys  1994     3.4   5733.0
# 8     9     Nosferatu: Original Version  1929     3.5   5651.0
# 9    10                    Nick of Time  1995     3.4   5333.0
# 10   11                 Broken Blossoms  1919     3.3   5367.0
# 11   12                       Big Night  1996     3.6   6561.0
# 12   13           The Birth of a Nation  1915     2.9  12118.0
# 13   14            The Boys from Brazil  1978     3.6   7417.0
# ...

# %%
af.info()
#Total number of enteries in the original dataset = 49590
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49590 entries, 0 to 49589
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S/N      49590 non-null  int64
#  1   Title    49590 non-null  object
#  2   Year     49590 non-null  int64
#  3   Rating   10814 non-null  float64
#  4   Watched  45836 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.9+ MB

# %%
af.isna().sum()
# Out:
# S/N            0
# Title          0
# Year           0
# Rating     38776
# Watched     3754
# dtype: int64

# %%
af['Rating']
# Out:
# 0        3.9
# 1        3.5
# 2        3.2
# 3        2.8
# 4        2.8
#         ...
# 49585    2.8
# 49586    NaN
# 49587    NaN
# 49588    2.7
# 49589    2.7
# Name: Rating, Length: 49590, dtype: float64

# %%
af.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49585    False
# 49586    False
# 49587    False
# 49588    False
# 49589    False
# Length: 49590, dtype: bool

# %%
af.duplicated().count()
# Out:
# 49590

# %%
print(af['Rating'].to_string())
# Out:
# 0        3.9
# 1        3.5
# 2        3.2
# 3        2.8
# 4        2.8
# 5        3.8
# 6        3.5
# 7        3.4
# 8        3.5
# 9        3.4
# 10       3.3
# 11       3.6
# 12       2.9
# 13       3.6
# 14       2.9
# 15       4.0
# 16       3.7
# 17       3.5
# 18       3.7
# 19       3.4
# 20       3.4
# 21       3.4
# 22       3.3
# 23       3.4
# 24       3.4
# 25       3.4
# 26       3.5
# 27       3.1
# 28       3.2
# 29       3.7
# 30       3.4
# 31       3.7
# 32       3.6
# 33       3.4
# 34       3.6
# 35       4.0
# 36       3.7
# 37       3.9
# 38       3.2
# 39       3.5
# 40       3.6
# 41       3.9
# 42       2.8
# 43       3.6
# 44       3.4
# 45       3.4
# 46       3.3
# 47       3.5
# 48       3.0
# 49       3.5
# 50       3.8
# 51       3.3
# 52       3.7
# 53       3.4
# 54       3.6
# 55       3.6
# 56       3.0
# 57       3.9
# 58       2.8
# 59       2.9
# 60       3.4
# 61       3.2
# 62       3.6
# 63       2.9
# 64       3.5
# 65       3.2
# ...

# %%
# drop empty values
af.dropna(inplace = True)

# %%
print(af.to_string())
# Out:
#          S/N                                                                                                      Title  Year  Rating  Watched
# 0          1                                                                             The Nightmare Before Christmas  1993     3.9   4568.0
# 1          2                                                                                                  The Mummy  1932     3.5   4388.0
# 2          3                                                                                       Orphans of the Storm  1921     3.2   9062.0
# 3          4                                                                                       The Object of Beauty  1991     2.8   6150.0
# 4          5                                                                                                 Night Tide  1963     2.8   5126.0
# ...

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7060 entries, 0 to 49585
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S/N      7060 non-null   int64
#  1   Title    7060 non-null   object
#  2   Year     7060 non-null   int64
#  3   Rating   7060 non-null   float64
#  4   Watched  7060 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 330.9+ KB

# %%
# Total Number of enteries after dropping all empty values  = 7060

# %%
#total number of unique movies = 6992

# %%
af['Title'].value_counts()
# Out:
# Believe                             2
# Easy Money                          2
# I Am                                2
# The Hole                            2
# Mutants                             2
#                                    ..
# The Hamiltons                       1
# After the Wedding                   1
# Jump In!                            1
# National Lampoon's TV: The Movie    1
# Silver Bells                        1
# Name: Title, Length: 6992, dtype: int64

# %%
af['Title'].unique()
# Out:
# array(['The Nightmare Before Christmas', 'The Mummy',
#        'Orphans of the Storm', ...,
#        "Lady Gaga &#38; The Muppets' Holiday Spectacular", 'Sunset Strip',
#        'Silver Bells'], dtype=object)

# %%
#total number of unique movies = 6992
af['Title'].nunique()
# Out:
# 6992

# %%
af['Rating']
# Out:
# 0        3.9
# 1        3.5
# 2        3.2
# 3        2.8
# 4        2.8
#         ...
# 49581    2.4
# 49582    3.1
# 49583    3.0
# 49584    3.5
# 49585    2.8
# Name: Rating, Length: 7060, dtype: float64

# %%
# The N0 of movies that have 4.5 ratings = 4
af[['Title','Rating']]
# Out:
#                                                   Title  Rating
# 0                        The Nightmare Before Christmas     3.9
# 1                                             The Mummy     3.5
# 2                                  Orphans of the Storm     3.2
# 3                                  The Object of Beauty     2.8
# 4                                            Night Tide     2.8
# ...                                                 ...     ...
# 49581                          Mumfie's White Christmas     2.4
# 49582  Lady Gaga &#38; The Muppets' Holiday Spectacular     3.1
# 49583                                      Sunset Strip     3.0
# 49584                                      Silver Bells     3.5
# 49585                                 Winter Wonderland     2.8
#
# [7060 rows x 2 columns]

# %%
af[['Title','Year', 'Rating']].groupby(['Rating'], sort =False).count()
# Out:
#         Title  Year
# Rating
# 3.9       342   342
# 3.5       562   562
# 3.2       518   518
# 2.8       305   305
# 3.8       413   413
# 3.4       563   563
# 3.3       544   544
# 3.6       588   588
# 2.9       356   356
# 4.0       204   204
# 3.7       543   543
# 3.1       501   501
# 3.0       447   447
# 2.5       152   152
# 2.7       230   230
# 4.1       117   117
# 2.6       157   157
# 2.4       109   109
# 2.2        53    53
# 4.2        71    71
# 2.1        72    72
# 4.3        22    22
# 1.9        25    25
# 2.3        99    99
# 2.0        22    22
# 1.8        18    18
# 4.4         9     9
# 4.5         4     4
# 1.7        10    10
# 1.6         4     4

# %%
# Which movie has highest number of downloads? : Example 8 Hour 23.976 Remote Content
# Which movie has least number of downloads? Trailer: Pain
af.sort_values('Watched')
# Out:
#          S/N                                 Title  Year  Rating  Watched
# 40150  40151                         Trailer: Pain  2012     3.6     52.0
# 41081  41082                  Trailer: Get to Work  2012     3.3     55.0
# 41082  41083                Trailer: Give and Take  2012     3.3     66.0
# 43166  43167                      Trailer: Emperor  2013     3.1     67.0
# 40149  40150                Trailer: Lift the Veil  2012     3.6     69.0
# ...      ...                                   ...   ...     ...      ...
# 1831    1832               Dr. Mabuse: The Gambler  1922     3.1  16422.0
# 22381  22382                        Heaven's Story  2010     2.3  16736.0
# 2423    2424                     The Best of Youth  2003     3.9  22024.0
# 12303  12304                 Example 8 Hour 23.976  2010     3.2  28813.0
# 22216  22217  Example 8 Hour 23.976 Remote Content  2010     3.0  28813.0
#
# [7060 rows x 5 columns]

# %%
# What is the total number of movies produced in 2014?
af.loc[af['Year']==2014]
# Out:
#          S/N                 Title  Year  Rating  Watched
# 49560  49561  The Square (Trailer)  2014     3.6    154.0

# %%
af.loc[af['Year']==2014].count()
# Out:
# S/N        1
# Title      1
# Year       1
# Rating     1
# Watched    1
# dtype: int64

# %%
What is the total number of movies produced in 1990?
af.loc[af['Year']==1990]
# Out:
#          S/N                                  Title  Year  Rating  Watched
# 35        36                         Into the Woods  1990     4.0   9077.0
# 39        40                       Internal Affairs  1990     3.5   6885.0
# 69        70                        Another 48 Hrs.  1990     3.5   5723.0
# 82        83                              Lionheart  1990     3.5   6301.0
# 84        85               The Hunt for Red October  1990     4.0   8106.0
# 106      107                           The Grifters  1990     3.4   6620.0
# 150      151          Child's Play 2: Chucky's Back  1990     3.2   5054.0
# 197      198                          The Two Jakes  1990     3.1   8251.0
# 404      405                            Bloodfist 2  1990     3.0   5054.0
# 411      412                              Ghost Dad  1990     3.3   5041.0
# 451      452                The Rescuers Down Under  1990     3.9   4627.0
# ...

# %%
af.loc[af['Year']==1990].count()
# Out:
# S/N        49
# Title      49
# Year       49
# Rating     49
# Watched    49
# dtype: int64

# %%
af.loc[af['Year'].isin([2014,1990])]
# Out:
#          S/N                                  Title  Year  Rating  Watched
# 35        36                         Into the Woods  1990     4.0   9077.0
# 39        40                       Internal Affairs  1990     3.5   6885.0
# 69        70                        Another 48 Hrs.  1990     3.5   5723.0
# 82        83                              Lionheart  1990     3.5   6301.0
# 84        85               The Hunt for Red October  1990     4.0   8106.0
# 106      107                           The Grifters  1990     3.4   6620.0
# 150      151          Child's Play 2: Chucky's Back  1990     3.2   5054.0
# 197      198                          The Two Jakes  1990     3.1   8251.0
# 404      405                            Bloodfist 2  1990     3.0   5054.0
# 411      412                              Ghost Dad  1990     3.3   5041.0
# 451      452                The Rescuers Down Under  1990     3.9   4627.0
# ...

# %%
af['Title'].iloc[45]
# Out:
# 'Drop Zone'
